# %% [markdown]
# <a href="https://colab.research.google.com/github/mugureeDOTcom/DataScience-Internsavy/blob/main/mall_customers_python_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
###IMPORTING LIBRARIES
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### **PREPROCESSING**

# %%
##LOADING THE DATASET
url ="/content/Mall_Customers.csv"
mall= pd.read_csv(url)

# %%
##CHECKING THE DATASET TOP
mall.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
##CHECKING THE DATASET BOTTOM
mall.tail()
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
##SHAPE OF THE DATASET
mall.shape
# Out:
# (200, 5)

# %%
##CHEKING THE DATA TYPES
mall.dtypes
# Out:
# CustomerID                 int64
# Genre                     object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %%
##INFORMATION ON THE DATASET
mall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
##NULL VALUES
mall.isnull()
# Out:
#      CustomerID  Genre    Age  Annual Income (k$)  Spending Score (1-100)
# 0         False  False  False               False                   False
# 1         False  False  False               False                   False
# 2         False  False  False               False                   False
# 3         False  False  False               False                   False
# 4         False  False  False               False                   False
# ..          ...    ...    ...                 ...                     ...
# 195       False  False  False               False                   False
# 196       False  False  False               False                   False
# 197       False  False  False               False                   False
# 198       False  False  False               False                   False
# 199       False  False  False               False                   False
#
# [200 rows x 5 columns]

# %%
##SUM OF THE NULL
mall.isnull().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %% [markdown]
# ###**UNIVARIATE ANALYSIS**

# %%
####age column
plt.figure(figsize=(8,6))
plt.hist(mall['Age'], bins=10, color='green', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of the Age')
plt.show()

# %%
age_mode = mall['Age'].mode().values[0]
age_mean = mall['Age'].mean()
age_max = mall['Age'].max()
age_min = mall['Age'].min()
print("Mode of age:", age_mode)
print("Mean of age:", age_mean)
print("Maximum age:", age_max)
print("Minimum age:", age_min)
# Out:
# Mode of age: 32
# Mean of age: 38.85
# Maximum age: 70
# Minimum age: 18

# %%
####gender column
plt.figure(figsize=(8,6))
plt.hist(mall['Genre'], bins=10, color='pink', edgecolor='black')
plt.xlabel('Genre')
plt.ylabel('Frequency')
plt.title('Histogram of the Genre')
plt.show()

# %%
####annual income column
plt.figure(figsize=(8,6))
plt.hist(mall['Annual Income (k$)'], bins=10, color='purple', edgecolor='black')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Frequency')
plt.title('Histogram of the Annual Income (k$)')
plt.show()

# %%
annual_mode = mall['Annual Income (k$)'].mode().values[0]
annual_mean = mall['Annual Income (k$)'].mean()
annual_max = mall['Annual Income (k$)'].max()
annual_min = mall['Annual Income (k$)'].min()
print("Mode of annual:", annual_mode)
print("Mean of annual:", annual_mean)
print("Maximum annual:", annual_max)
print("Minimum annual:", annual_min)
# Out:
# Mode of annual: 54
# Mean of annual: 60.56
# Maximum annual: 137
# Minimum annual: 15

# %%
####spending score column
plt.figure(figsize=(8,6))
plt.hist(mall['Spending Score (1-100)'], bins=10, color='orange', edgecolor='black')
plt.xlabel('Spending Score (1-100)')
plt.ylabel('Frequency')
plt.title('Histogram of the Spending Score (1-100)')
plt.show()

# %%
spending_mode = mall['Spending Score (1-100)'].mode().values[0]
spending_mean = mall['Spending Score (1-100)'].mean()
spending_max = mall['Spending Score (1-100)'].max()
spending_min = mall['Spending Score (1-100)'].min()
print("Mode of annual:", spending_mode)
print("Mean of annual:", spending_mean)
print("Maximum annual:", spending_max)
print("Minimum annual:", spending_min)
# Out:
# Mode of annual: 42
# Mean of annual: 50.2
# Maximum annual: 99
# Minimum annual: 1

# %% [markdown]
# ### **BIVARIATE ANALYSIS**

# %%
###Pairplots
sns.pairplot(mall)
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter plot: Age vs. Spending Score
plt.scatter(mall['Age'], mall['Spending Score (1-100)'])
plt.xlabel('Age')
plt.ylabel('Spending Score (1-100)')
plt.title('Scatter Plot: Age vs. Spending Score')
plt.show()

# %% [markdown]
# ### **MULTIVARIATE ANALYSIS**

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Select the columns for PCA
features = mall[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']]

# Standardize the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Perform PCA
pca = PCA()
pca.fit(scaled_features)

# Get the principal components
components = pca.components_

# Get the explained variance ratio
explained_variance = pca.explained_variance_ratio_

# Create a DataFrame to store the results
pca_results = pd.DataFrame({
    'Component': range(1, len(explained_variance) + 1),
    'Explained Variance Ratio': explained_variance
})

# Print the results
print("Principal Components:")
print(components)
print("\nExplained Variance Ratio:")
print(pca_results)

# Visualize the explained variance ratio
plt.bar(range(1, len(explained_variance) + 1), explained_variance)
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.title('Explained Variance Ratio for Principal Components')
plt.show()
# Out:
# Principal Components:
# [[ 0.70638235 -0.04802398 -0.70619946]
#  [ 0.03014116  0.9988316  -0.03777499]
#  [-0.70718844 -0.00539792 -0.70700451]]
#
# Explained Variance Ratio:
#    Component  Explained Variance Ratio
# 0          1                  0.442662
# 1          2                  0.333084
# 2          3                  0.224255
